# %%
# %matplotlib inline
import plotter as pltr

# %%
pltr.plotThroughput(pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.tls_plugins + pltr.overlay_sec_plugins)

# %%
pltr.plotCPU(pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.tls_plugins + pltr.overlay_sec_plugins)

# %%
pltr.plotPingPongLatency(pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.tls_plugins + pltr.overlay_sec_plugins)
