# %%
# %matplotlib inline
import plotter as pltr

# %%
pltr.plotReliableThroughput(pltr.udp_plugins + pltr.tcp_plugins)

# %%
pltr.plotReliableCPU(pltr.udp_plugins + pltr.tcp_plugins)

# %%
pltr.plotReliablePingPongLatency(pltr.udp_plugins + pltr.tcp_plugins)

# %%
pltr.plotSecureReliableThroughput(pltr.tls_plugins + pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.overlay_sec_plugins)

# %%
pltr.plotSecureReliableCPU(pltr.tls_plugins + pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.overlay_sec_plugins)

# %%
pltr.plotSecureReliablePingPongLatency(pltr.tls_plugins + pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.overlay_sec_plugins)

# %%
pltr.plotBestEffortThroughput(pltr.udp_plugins + pltr.tcp_plugins)

# %%
 pltr.plotBestEffortSecureThroughput(pltr.udp_dds_secure_plugins + pltr.tcp_dds_secure_plugins + pltr.tls_plugins + pltr.overlay_sec_plugins)

# %%
pltr.plotMulticastThroughput(pltr.multicast_plugins)
